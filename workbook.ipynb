# %% [markdown]
# # <center>World Map Geovisualization using Folium and Covid Data

# %% [markdown]
# ### <center>Instructor: Vinita Silaparasetty

# %% [markdown]
# ### Import Libraries

# %%
import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %% [markdown]
# ### Generate Base Map

# %%
conn=http.client.HTTPSConnection("api.covid19api.com")
payload=''
headers={}
conn.request("GET","/summary",payload,headers)
res=conn.getresponse()
data=res.read().decode('UTF-8')

# %% [markdown]
# ### Access Data via API

# %%
covid1=json.loads(data)

# %% [markdown]
# ### Convert Data to JSON

# %% [markdown]
# ### Normalize Data

# %%
pd.json_normalize(covid1['Countries'],sep=",")
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan            31           38196
# 1           Albania          AL         albania            93            9606
# 2           Algeria          DZ         algeria           339           44833
# 3           Andorra          AD         andorra             8            1184
# 4            Angola          AO          angola            75            2729
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         vietnam             0            1044
# 182  Western Sahara          EH  western-sahara             0              10
# 183           Yemen          YE           yemen             4            1962
# 184          Zambia          ZM          zambia           284           12381
# 185        Zimbabwe          ZW        zimbabwe            62            6559
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            4         1406           142           29231
# 1            6          290           227            5441
# 2            8         1518           249           31493
# 3            0           53             0             908
# 4            1          109            13            1084
# ..         ...          ...           ...             ...
# 181          0           34            28             735
# 182          0            1             0               8
# 183          4          570            29            1160
# 184          2          290            10           11479
# 185          1          203            20            5241
#
#                      Date
# 0    2020-09-03T04:07:35Z
# 1    2020-09-03T04:07:35Z
# 2    2020-09-03T04:07:35Z
# 3    2020-09-03T04:07:35Z
# 4    2020-09-03T04:07:35Z
# ..                    ...
# 181  2020-09-03T04:07:35Z
# 182  2020-09-03T04:07:35Z
# 183  2020-09-03T04:07:35Z
# 184  2020-09-03T04:07:35Z
# 185  2020-09-03T04:07:35Z
#
# [186 rows x 10 columns]

# %% [markdown]
# ### Convert to Pandas DataFrame

# %%
df=pd.DataFrame(covid1['Countries'])
df
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan            31           38196
# 1           Albania          AL         albania            93            9606
# 2           Algeria          DZ         algeria           339           44833
# 3           Andorra          AD         andorra             8            1184
# 4            Angola          AO          angola            75            2729
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         vietnam             0            1044
# 182  Western Sahara          EH  western-sahara             0              10
# 183           Yemen          YE           yemen             4            1962
# 184          Zambia          ZM          zambia           284           12381
# 185        Zimbabwe          ZW        zimbabwe            62            6559
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            4         1406           142           29231
# 1            6          290           227            5441
# 2            8         1518           249           31493
# 3            0           53             0             908
# 4            1          109            13            1084
# ..         ...          ...           ...             ...
# 181          0           34            28             735
# 182          0            1             0               8
# 183          4          570            29            1160
# 184          2          290            10           11479
# 185          1          203            20            5241
#
#                      Date Premium
# 0    2020-09-03T04:07:35Z      {}
# 1    2020-09-03T04:07:35Z      {}
# 2    2020-09-03T04:07:35Z      {}
# 3    2020-09-03T04:07:35Z      {}
# 4    2020-09-03T04:07:35Z      {}
# ..                    ...     ...
# 181  2020-09-03T04:07:35Z      {}
# 182  2020-09-03T04:07:35Z      {}
# 183  2020-09-03T04:07:35Z      {}
# 184  2020-09-03T04:07:35Z      {}
# 185  2020-09-03T04:07:35Z      {}
#
# [186 rows x 11 columns]

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
covid2=df.drop(columns=['CountryCode','Slug','Date','Premium'],axis=1)
covid2
# Out:
#             Country  NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  \
# 0       Afghanistan            31           38196          4         1406
# 1           Albania            93            9606          6          290
# 2           Algeria           339           44833          8         1518
# 3           Andorra             8            1184          0           53
# 4            Angola            75            2729          1          109
# ..              ...           ...             ...        ...          ...
# 181        Viet Nam             0            1044          0           34
# 182  Western Sahara             0              10          0            1
# 183           Yemen             4            1962          4          570
# 184          Zambia           284           12381          2          290
# 185        Zimbabwe            62            6559          1          203
#
#      NewRecovered  TotalRecovered
# 0             142           29231
# 1             227            5441
# 2             249           31493
# 3               0             908
# 4              13            1084
# ..            ...             ...
# 181            28             735
# 182             0               8
# 183            29            1160
# 184            10           11479
# 185            20            5241
#
# [186 rows x 7 columns]

# %% [markdown]
# ### Generate Base Map

# %%
m=folium.Map(titles="Stamen Terrain",min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Obtain Geodata
#
# geodata url: https://raw.githubusercontent.com/python-visualization/folium/master/examples/data
#
# geo data file: world-countries.json

# %%
url='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes=f'{url}/world-countries.json'

# %% [markdown]
# ### Obtain Geodata
#
# geodata url: https://raw.githubusercontent.com/python-visualization/folium/master/examples/data
#
# geo data file: world-countries.json

# %% [markdown]
# ### Generate Choropleth Map Layer

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zoom=2,
    name='Covid-19',
    data=covid2,
    columns=['Country','TotalConfirmed'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    nan_fill_color='black',
    legend_name='Total Confirmed Covid Cases',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Markers

# %%
covid2.update(covid2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid2.update(covid2['TotalRecovered'].map('Total Recovered:{}'.format))

# %% [markdown]
# coordinates of countries: https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv

# %%
coordinates=pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')

# %%
coordinates
# Out:
#       latitude   longitude            Country
# 0    33.939110   67.709953        Afghanistan
# 1    41.153332   20.168331            Albania
# 2    28.033886    1.659626            Algeria
# 3   -14.270972 -170.132217     American Samoa
# 4    42.546245    1.601554            Andorra
# ..         ...         ...                ...
# 239 -13.768752 -177.156097  Wallis and Futuna
# 240  24.215527  -12.885834     Western Sahara
# 241  15.552727   48.516388              Yemen
# 242 -13.133897   27.849332             Zambia
# 243 -19.015438   29.154857           Zimbabwe
#
# [244 rows x 3 columns]

# %%
covid_final=pd.merge(covid2,coordinates,on='Country')

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude,point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country,point.TotalConfirmed,point.TotalRecovered],
                       fill_color='#000000').add_to(m)

# %%
covid_final.apply(plotDot,axis=1)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Base Map

# %%
m1=folium.Map(titles='StamenToner',min_zoom=2)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Heat Map Layer

# %%
deaths=covid_final['TotalDeaths'].astype(float)
lat=covid_final['latitude'].astype(float)
lon=covid_final['longitude'].astype(float)
m1.add_child(HeatMap(zip(lat,lon,deaths),radius =0))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Marker

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude,point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country,point.TotalDeaths],
                       fill_color='#000000').add_to(m1)

# %%
covid_final.apply(plotDot,axis=1)
m1.fit_bounds(m1.get_bounds())
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
